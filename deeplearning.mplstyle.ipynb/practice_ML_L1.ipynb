# %% [markdown]
# ## lab_1

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train{y_train}")
# Out:
# x_train = [1. 2.]
# y_train[300. 500.]

# %%
print(f"x_train.shape = {x_train.shape}")
m = x_train.shape[0]
print(f"Number of tranning is : { m }")
# Out:
# x_train.shape = (2,)
# Number of tranning is : 2

# %% [markdown]
# ## OR

# %%
m = len(x_train)
print(f"number of tranning in : {m}")
# Out:
# number of tranning in : 2

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
plt.scatter(x_train, y_train , marker='x', c="r")
plt.title('Housing Price')
plt.ylabel("price (in 1000s doller)")
plt.xlabel('size (1000sqft)')
plt.show()

# %%
w = 100
b = 100
print(f'w = {w}')
print(f'b = {b}')
# Out:
# w = 100
# b = 100

# %%
def compute_model_output(x, w, b):

    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range (m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)
plt.plot(x_train, tmp_f_wb, c='b', label='Our Pridiction')
plt.scatter(x_train, y_train, marker = 'x', c = 'r', label = 'Actual Value' )
plt.title('Houseing Price')
plt.ylabel('prince (in 1000s of doller)')
plt.xlabel('size (1000sqft)')
plt.legend()
plt.show()

# %%
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i + b
print(f"${cost_1200sqft:.0f}, thousand doller")
# Out:
# $340, thousand doller

# %%
w = 600
b = 200
x_i = 1.6
cost_1200sqft = w*x_i+b
print(f"{cost_1200sqft:.0f},thousand doller")
# Out:
# 1160,thousand doller

# %% [markdown]
# ## lab_2
